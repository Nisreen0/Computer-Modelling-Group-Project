# %%
#------------------------------------------------------------------------------------------------------------
function Trapezium(f, a, b, n)
    h=(b-a)/n
    s = 0
    for i in 1:n
        s += 0.5 * (f(a + (i-1)*h) + f(a + i*h))
    end
    return h*s
end
#------------------------------------------------------------------------------------------------------------
function MC(f, A, B, C, D, N)
    count = 0
    for n = 1:N
        x,y = (B - rand()*(B-A)), (D - rand()*(D-C))
        if y > 0 && y <= f(x)
            count += 1
        elseif y < 0 && y >= f(x)
            count -= 1
        end
    end
    return (count/N)*((B-A)*(D-C))
end
#------------------------------------------------------------------------------------------------------------
function runge_kutta( f, h, y_0, t_0, t_1 )   
    
    #author: Harry Cai
    
t = t_0:h:t_1;
y = zeros(length(t));
y[1] = y_0;

for i = 1:length(t)-1
    k1 = f(t[i], y[i]);
    k2 = f(t[i]+h/2, y[i]+h*k1/2);
    k3 = f(t[i]+h/2, y[i]+h*k2/2);
    k4 = f(t[i]+h, y[i]+h*k3);
    y[i+1] = y[i] + (h/6) * (k1 + 2*k2 + 2*k3 + k4);
end

return y    
    
end

function rk_integration(f, a, b, n)
    steps = div(n, 4) # number of steps, which is n/4 as each step requires 4 evaluations of f
    F(t, y) = f(t);
    t = a:(b - a)/steps:b;
    h = t[2]-t[1];
    y = runge_kutta(F, h, 0, a, b);
    return y[steps];
end
#------------------------------------------------------------------------------------------------------------

using SpecialFunctions
using Suppressor
using Plots
plotlyjs()

runs = 1000

trErrors = zeros(runs)
trTimes = zeros(runs)

mcErrors = zeros(runs)
mcTimes = zeros(runs)

rkErrors = zeros(runs)
rkTimes = zeros(runs)

for i = 1 : runs
    
    scale = 10*rand()
    a = 10.0^(3*rand() - 4)
    b = 10.0^(3*rand())
    f(x) = scale*sin(1/x)
    
    @suppress tempTrueVal = scale*((b*sin(1/b) - cosint(1/b)) - (a*sin(1/a) - cosint(1/a)))
    
    tic()
    tempVal = Trapezium(f, a, b, 100)
    @suppress tempTime = toc()
    trErrors[i] = abs((tempTrueVal - tempVal)/tempTrueVal)
    trTimes[i] = tempTime
    
    tic()
    tempVal = MC(f, a, b, -scale, scale, 1000)
    @suppress tempTime = toc()
    mcErrors[i] = abs((tempTrueVal - tempVal)/tempTrueVal)
    mcTimes[i] = tempTime
    
    tic()
    tempVal = rk_integration(f, a, b, 100)
    @suppress tempTime = toc()
    rkErrors[i] = abs((tempTrueVal - tempVal)/tempTrueVal)
    rkTimes[i] = tempTime
end

trAvgError = mean(trErrors)
trVariance = var(trErrors)
trAvgTime = mean(trTimes)

mcAvgError = mean(mcErrors)
mcVariance = var(mcErrors)
mcAvgTime = mean(mcTimes)

rkAvgError = mean(rkErrors)
rkVariance = var(rkErrors)
rkAvgTime = mean(rkTimes)

println("Average Trapezium Rule Relative Error: ", trAvgError)
println("Trapezium Rule Variance: ", trVariance)
println("Average Trapezium Rule Time: ", trAvgTime)
println()
println("Average Monte Carlo Relative Error: ", mcAvgError)
println("Monte Carlo Variance: ", mcVariance)
println("Average Monte Carlo Time: ", mcAvgTime)
println()
println("Average Runge-Kutta Relative Error: ", rkAvgError)
println("Runge-Kutta Variance: ", rkVariance)
println("Average Runge-Kutta Time: ", rkAvgTime)

methods = ["Trapezium Rule", "Monte Carlo", "Runge-Kutta"]
errors = [trAvgError, mcAvgError, rkAvgError]
vars = [trVariance, mcVariance, rkVariance]
times = [trAvgTime, mcAvgTime, rkAvgTime]

fig1 = bar(methods,errors,title="Relative Error",xlabel="Method",ylabel="Relative Error",legend=false)
fig2 = bar(methods,vars,title="Variance",xlabel="Method",ylabel="Variance",legend=false)
fig3 = bar(methods,times,title="Running Times",xlabel="Method",ylabel="Running Time (s)",legend=false)

display(fig1)
display(fig2)
display(fig3)
# Out:
# <div id="96de6f32-030a-4a3b-a2c7-2c29bebd24cd" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('96de6f32-030a-4a3b-a2c7-2c29bebd24cd', [{"xaxis":"x","colorbar":{"title":""},"yaxis":"y","orientation":"v","x":[0.5,1.5,2.5],"showlegend":true,"name":"y1","marker":{"color":["rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)"],"line":{"width":1}},"y":[0.08782714582810133,0.14628297015714276,0.13261174452219823],"type":"bar","width":0.8}],
#                {"showlegend":false,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.5,1.5,2.5],"visible":true,"ticks":"inside","range":[0.09999999999999998,2.9],"domain":[0.10609871682706327,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Method","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["Trapezium Rule","Monte Carlo","Runge-Kutta"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Relative Error","xref":"paper","x":0.5497685185185185}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.0,0.025,0.05,0.07500000000000001,0.1,0.125],"visible":true,"ticks":"inside","range":[0.0,0.14628297015714276],"domain":[0.07581474190726165,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Relative Error","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["0.000","0.025","0.050","0.075","0.100","0.125"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x"},"width":600}, {showLink: false});
#
#     });
#  </script>
# <div id="da67a1c1-6498-4cca-aabc-dfffe7df3ac0" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('da67a1c1-6498-4cca-aabc-dfffe7df3ac0', [{"xaxis":"x","colorbar":{"title":""},"yaxis":"y","orientation":"v","x":[0.5,1.5,2.5],"showlegend":true,"name":"y1","marker":{"color":["rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)"],"line":{"width":1}},"y":[0.019010042887813026,0.02827787248345273,0.033407662488274294],"type":"bar","width":0.8}],
#                {"showlegend":false,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.5,1.5,2.5],"visible":true,"ticks":"inside","range":[0.09999999999999998,2.9],"domain":[0.09128390201224845,0.9934383202099738],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Method","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["Trapezium Rule","Monte Carlo","Runge-Kutta"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Variance","xref":"paper","x":0.5423611111111111}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.0,0.01,0.02,0.03],"visible":true,"ticks":"inside","range":[0.0,0.033407662488274294],"domain":[0.07581474190726165,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Variance","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["0.00","0.01","0.02","0.03"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x"},"width":600}, {showLink: false});
#
#     });
#  </script>
# <div id="5ae76457-921e-4496-9ada-5d5d26a8f732" class="plotly-graph-div"></div>
#
# <script>
#     window.PLOTLYENV=window.PLOTLYENV || {};
#     window.PLOTLYENV.BASE_URL="https://plot.ly";
#     require(['plotly'], function(Plotly) {
#         Plotly.newPlot('5ae76457-921e-4496-9ada-5d5d26a8f732', [{"xaxis":"x","colorbar":{"title":""},"yaxis":"y","orientation":"v","x":[0.5,1.5,2.5],"showlegend":true,"name":"y1","marker":{"color":["rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)","rgba(0, 154, 250, 1.000)"],"line":{"width":1}},"y":[6.296265999999999e-5,0.00016730237199999998,0.00010722510700000004],"type":"bar","width":0.8}],
#                {"showlegend":false,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.5,1.5,2.5],"visible":true,"ticks":"inside","range":[0.09999999999999998,2.9],"domain":[0.1357283464566929,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Method","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["Trapezium Rule","Monte Carlo","Runge-Kutta"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[{"yanchor":"top","xanchor":"center","rotation":-0.0,"y":1.0,"font":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":20},"yref":"paper","showarrow":false,"text":"Running Times","xref":"paper","x":0.5645833333333333}],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.0,5.0e-5,0.0001,0.00015000000000000001],"visible":true,"ticks":"inside","range":[0.0,0.00016730237199999998],"domain":[0.07581474190726165,0.9415463692038496],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"Running Time (s)","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["0.00000","0.00005","0.00010","0.00015"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"x"},"width":600}, {showLink: false});
#
#     });
#  </script>
# Average Trapezium Rule Relative Error: 0.08782714582810133
# Trapezium Rule Variance: 0.019010042887813026
# Average Trapezium Rule Time: 6.296265999999999e-5
#
# Average Monte Carlo Relative Error: 0.14628297015714276
# Monte Carlo Variance: 0.02827787248345273
# Average Monte Carlo Time: 0.00016730237199999998
#
# Average Runge-Kutta Relative Error: 0.13261174452219823
# Runge-Kutta Variance: 0.033407662488274294
# Average Runge-Kutta Time: 0.00010722510700000004
